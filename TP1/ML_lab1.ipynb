# %% [markdown]
# # Lab 1 : Reminders on data manipulation and visualisation using Python : Titanic Dataset
#
# This webpage is a "Jupyter Notebook" : It is a special type of Python file that you can open and execute using a web browser. This document is made of plain text containing questions and explanations, as well as fields with code, which sometimes will be empty and for you to fill up or to complete.
#
# For a Jupyter Notebook to work properly, you need to run the different code fields after writing them. This means, that unlike in a regular Python file, if you edit something at the beginning of the page, you may have to re-run exerything in order for the effects to apply on all future fields and variables.
# Please note that as we will progress in this course, there will be less and less pre-filled code, and at some point, you will have to create the full code/notebook yourself.
#
# The goal of this first lab is to remind you some of the basics of handling Data in python, basic visualisation and statistic functions, and to use some simple classifiers.

# %% [markdown]
# ## Part A: RMS Titanic - loading and visualizing
#
# In this first lab, we will study a dataset dealing with the passengers of the RMS Titanic. This dataset was built using data found about the original passengers and is therefore incomplete.
#
# In the next block, you will find a very important piece of code to import some basic libraries that you will use for pretty much all labs:
# - pandas for data and files management
# - numpy for basic mathematics in Python
# - matplotlib for graphics and visuals
# - seaborn : another graphics library

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Question 1 : Open the file "titanic_full.csv" with a regular text editor. What can you tell about the method used to separate the different columns ? Use your answer to this question to fill up the code below and open the file in Python using the pandas library.

# %%
#fill the blanks
titanic_data = pd.read_csv("D:/ISEP/I1 - Intro AnaDat/TP1 - manip & vis 1/titanic_full.csv",sep=",",index_col=0);

# %% [markdown]
# Now that you have loaded the data as a pandas dataframe named "titanic-data", we will take a look at some basic properties of this object.
# Try the following properties and functions, look at the result and explain what they do:
# - The head() function
# - The shape property
# - The dtypes property

# %%
titanic_data.head()
# Out:
#              Survived  Pclass       Name  \
# PassengerId
# 1                   0       3     Braund
# 2                   1       1    Cumings
# 3                   1       3  Heikkinen
# 4                   1       1   Futrelle
# 5                   0       3      Allen
#
#                                                 FullName     Sex   Age  SibSp  \
# PassengerId
# 1                                        Mr. Owen Harris    male  22.0      1
# 2             Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 3                                            Miss. Laina  female  26.0      0
# 4                     Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                                      Mr. William Henry    male  35.0      0
#
#              Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                0         A/5 21171   7.2500   NaN        S
# 2                0          PC 17599  71.2833   C85        C
# 3                0  STON/O2. 3101282   7.9250   NaN        S
# 4                0            113803  53.1000  C123        S
# 5                0            373450   8.0500   NaN        S

# %%
titanic_data.shape
# Out:
# (892, 12)

# %%
titanic_data.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# FullName     object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %% [markdown]
# <u>Answer 1:</u>
#
# *double click here to edit and write your answer*

# %% [markdown]
# #### Question 2 : One important thing to consider with this dataset is the number of missing data. Using the function .isnull() and the function .sum() of the dataframe object, find out where and how many missing data there are in this dataset.

# %%
titanic_data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# FullName      0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# Pandas dataframe allow for an easy access to the lines and columns of a dataset. For instance, the code below gives access to the column containing the age of the passengers.

# %%
titanic_data["Age"]
# Out:
# PassengerId
# 1      22.0
# 2      38.0
# 3      26.0
# 4      35.0
# 5      35.0
#        ...
# 888    19.0
# 889     NaN
# 890    26.0
# 891    32.0
# 892    45.0
# Name: Age, Length: 892, dtype: float64

# %% [markdown]
# Likewise, the .loc and .iloc properties are useful to select singles lines from a dataset :

# %%
titanic_data.loc[30]
# Out:
# Survived             0
# Pclass               3
# Name          Todoroff
# FullName     Mr. Lalio
# Sex               male
# Age                NaN
# SibSp                0
# Parch                0
# Ticket          349216
# Fare            7.8958
# Cabin              NaN
# Embarked             S
# Name: 30, dtype: object

# %%
titanic_data.iloc[30]
# Out:
# Survived                 0
# Pclass                   1
# Name             Uruchurtu
# FullName     Don. Manuel E
# Sex                   male
# Age                   40.0
# SibSp                    0
# Parch                    0
# Ticket            PC 17601
# Fare               27.7208
# Cabin                  NaN
# Embarked                 C
# Name: 31, dtype: object

# %% [markdown]
# #### Question 3 : Based on the 2 previous code blocks and the internet, explain the difference between .loc and .iloc .

# %% [markdown]
# <u>Answer 3</u>
#
# - loc utilise la numérotation par l'index du jeu de données (qui ici commence à 1), mais pourrait très bien être une étiquette.
# - iloc utilise la numérotation des tableaux python (qui commence toujours à 0)

# %% [markdown]
# #### Question 4 : Using the previous answers, retrieve the following: a) the age of the passenger with PassengerID number 119, b) The family name of the passenger whose array index is 138.

# %%
#code à trou : age du passager avec le PassengerID 119
titanic_data["Age"].loc[119]
# Out:
# 24.0

# %%
#code à trou : nom du passager avec l'index 138 dans le tableau
titanic_data["Name"].iloc[138]
# Out:
# 'Osen'

# %% [markdown]
# In the example below, we show how to select only female passengers by using a filter based on the columns.

# %%
titanic_women = titanic_data[titanic_data['Sex']=='female']
titanic_women
# Out:
#              Survived  Pclass       Name  \
# PassengerId
# 2                   1       1    Cumings
# 3                   1       3  Heikkinen
# 4                   1       1   Futrelle
# 9                   1       3    Johnson
# 10                  1       2     Nasser
# ...               ...     ...        ...
# 883                 0       3   Dahlberg
# 886                 0       3       Rice
# 888                 1       1     Graham
# 889                 0       3   Johnston
# 892                 1       1      Brown
#
#                                                 FullName     Sex   Age  SibSp  \
# PassengerId
# 2             Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 3                                            Miss. Laina  female  26.0      0
# 4                     Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 9               Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                           Mrs. Nicholas (Adele Achem)  female  14.0      1
# ...                                                  ...     ...   ...    ...
# 883                                   Miss. Gerda Ulrika  female  22.0      0
# 886                       Mrs. William (Margaret Norton)  female  39.0      0
# 888                                 Miss. Margaret Edith  female  19.0      0
# 889                         Miss. Catherine Helen Carrie  female   NaN      1
# 892                                      Miss. Margareth  female  45.0      0
#
#              Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 2                0          PC 17599  71.2833   C85        C
# 3                0  STON/O2. 3101282   7.9250   NaN        S
# 4                0            113803  53.1000  C123        S
# 9                2            347742  11.1333   NaN        S
# 10               0            237736  30.0708   NaN        C
# ...            ...               ...      ...   ...      ...
# 883              0              7552  10.5167   NaN        S
# 886              5            382652  29.1250   NaN        Q
# 888              0            112053  30.0000   B42        S
# 889              2        W./C. 6607  23.4500   NaN        S
# 892              0             17610  27.1400   E23        C
#
# [315 rows x 12 columns]

# %% [markdown]
# #### Question 5 : Using a similar syntax and what you learn about the .loc property, propose a solution to filter the passengers accordingly: a) only the passengers whose Age is greater than 30 years old ; b) Passengers that embarked in Cherbourg and survived ; c) Passengers whose Age is unknown and did not survive.

# %%
titanic_30p = titanic_data[titanic_data['Age']>=30]
titanic_30p
# Out:
#              Survived  Pclass      Name  \
# PassengerId
# 2                   1       1   Cumings
# 4                   1       1  Futrelle
# 5                   0       3     Allen
# 7                   0       1  McCarthy
# 12                  1       1   Bonnell
# ...               ...     ...       ...
# 880                 1       1    Potter
# 882                 0       3    Markun
# 886                 0       3      Rice
# 891                 0       3    Dooley
# 892                 1       1     Brown
#
#                                                 FullName     Sex   Age  SibSp  \
# PassengerId
# 2             Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 4                     Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                                      Mr. William Henry    male  35.0      0
# 7                                          Mr. Timothy J    male  54.0      0
# 12                                       Miss. Elizabeth  female  58.0      0
# ...                                                  ...     ...   ...    ...
# 880                Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 882                                           Mr. Johann    male  33.0      0
# 886                       Mrs. William (Margaret Norton)  female  39.0      0
# 891                                          Mr. Patrick    male  32.0      0
# 892                                      Miss. Margareth  female  45.0      0
#
#              Parch    Ticket     Fare Cabin Embarked
# PassengerId
# 2                0  PC 17599  71.2833   C85        C
# 4                0    113803  53.1000  C123        S
# 5                0    373450   8.0500   NaN        S
# 7                0     17463  51.8625   E46        S
# 12               0    113783  26.5500  C103        S
# ...            ...       ...      ...   ...      ...
# 880              1     11767  83.1583   C50        C
# 882              0    349257   7.8958   NaN        S
# 886              5    382652  29.1250   NaN        Q
# 891              0    370376   7.7500   NaN        Q
# 892              0     17610  27.1400   E23        C
#
# [331 rows x 12 columns]

# %%
titanic_cherbourg_survived = titanic_data.loc[ (titanic_data['Embarked']=='C') & (titanic_data['Survived']==1) ]
titanic_cherbourg_survived
# Out:
#              Survived  Pclass        Name  \
# PassengerId
# 2                   1       1     Cumings
# 10                  1       2      Nasser
# 20                  1       3  Masselmani
# 32                  1       1     Spencer
# 37                  1       3       Mamee
# ...               ...     ...         ...
# 875                 1       2     Abelson
# 876                 1       3       Najib
# 880                 1       1      Potter
# 890                 1       1        Behr
# 892                 1       1       Brown
#
#                                                 FullName     Sex   Age  SibSp  \
# PassengerId
# 2             Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 10                           Mrs. Nicholas (Adele Achem)  female  14.0      1
# 20                                           Mrs. Fatima  female   NaN      0
# 32                 Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 37                                             Mr. Hanna    male   NaN      0
# ...                                                  ...     ...   ...    ...
# 875                         Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 876                              Miss. Adele Kiamie Jane  female  15.0      0
# 880                Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 890                                      Mr. Karl Howell    male  26.0      0
# 892                                      Miss. Margareth  female  45.0      0
#
#              Parch     Ticket      Fare Cabin Embarked
# PassengerId
# 2                0   PC 17599   71.2833   C85        C
# 10               0     237736   30.0708   NaN        C
# 20               0       2649    7.2250   NaN        C
# 32               0   PC 17569  146.5208   B78        C
# 37               0       2677    7.2292   NaN        C
# ...            ...        ...       ...   ...      ...
# 875              0  P/PP 3381   24.0000   NaN        C
# 876              0       2667    7.2250   NaN        C
# 880              1      11767   83.1583   C50        C
# 890              0     111369   30.0000  C148        C
# 892              0      17610   27.1400   E23        C
#
# [94 rows x 12 columns]

# %%
titanic_uage_died = titanic_data.loc[ (titanic_data['Age'].isnull()) & (titanic_data['Survived']==0) ]
titanic_uage_died
# Out:
#              Survived  Pclass           Name                       FullName  \
# PassengerId
# 6                   0       3          Moran                      Mr. James
# 27                  0       3           Emir              Mr. Farred Chehab
# 30                  0       3       Todoroff                      Mr. Lalio
# 43                  0       3         Kraeff                    Mr. Theodor
# 46                  0       3         Rogers               Mr. William John
# ...               ...     ...            ...                            ...
# 860                 0       3           Razi                     Mr. Raihed
# 864                 0       3           Sage      Miss. Dorothy Edith Dolly
# 869                 0       3  van Melkebeke                   Mr. Philemon
# 879                 0       3         Laleff                     Mr. Kristo
# 889                 0       3       Johnston   Miss. Catherine Helen Carrie
#
#                 Sex  Age  SibSp  Parch           Ticket     Fare Cabin  \
# PassengerId
# 6              male  NaN      0      0           330877   8.4583   NaN
# 27             male  NaN      0      0             2631   7.2250   NaN
# 30             male  NaN      0      0           349216   7.8958   NaN
# 43             male  NaN      0      0           349253   7.8958   NaN
# 46             male  NaN      0      0  S.C./A.4. 23567   8.0500   NaN
# ...             ...  ...    ...    ...              ...      ...   ...
# 860            male  NaN      0      0             2629   7.2292   NaN
# 864          female  NaN      8      2         CA. 2343  69.5500   NaN
# 869            male  NaN      0      0           345777   9.5000   NaN
# 879            male  NaN      0      0           349217   7.8958   NaN
# 889          female  NaN      1      2       W./C. 6607  23.4500   NaN
#
#             Embarked
# PassengerId
# 6                  Q
# 27                 C
# 30                 S
# 43                 C
# 46                 S
# ...              ...
# 860                C
# 864                S
# 869                S
# 879                S
# 889                S
#
# [125 rows x 12 columns]

# %% [markdown]
# #### Question 6 : The following code uses other basic and usefull pandas functions. Run it, and explain what it does.

# %%
#bloc de code à expliquer

def pourcentageDf(df):
    return 100*df.value_counts()/df.shape[0]

pctSH= pourcentageDf(titanic_data[titanic_data['Sex']=='male']['Survived'])
pctSF= pourcentageDf(titanic_data[titanic_data['Sex']=='female']['Survived'])

result = pd.concat([pctSH, pctSF], axis=1)
result.columns = ['Hommes','Femmes']
result
# Out:
#              Hommes     Femmes
# Survived
# 0         81.109185  25.714286
# 1         18.890815  74.285714

# %% [markdown]
# <u>Answer 6 :</u>
#
# It displays the survivor and dead persons by sex.

# %% [markdown]
# We will now check some basic numpy, pandas and other python functions for statistics and data visualization.
#
# Let us first use the describe() function which returns some basic statistics:

# %%
titanic_data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  892.000000  892.000000  715.000000  892.000000  892.000000  892.000000
# mean     0.384529    2.307175   29.720517    0.522422    0.381166   32.198531
# std      0.486757    0.836750   14.527595    1.102264    0.805706   49.665824
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.250000    0.000000    0.000000    7.917700
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# #### Question 7 : Explain what are the different lines (which statistics is computed) ?

# %% [markdown]
# <u>Answer 7 :</u>
# - count : number of non-null lines
# - mean : the mean
# - std : the standard deviation
# - min : the min value
# - max : the max value
# - 25%, 50%, 75% : the value for the 3 first quartiles.

# %% [markdown]
# We will now use a pie plot (camembert en français) to display the percentage of survivors :

# %%
titanic_data['Survived'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #### Question 8 : Using the previous example, display the passengers according to their class (1st, 2nd, 3rd)

# %%
#camembert par classe
titanic_data['Pclass'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# We will now display the survival chances of the passengers according to the class in which they travelled. To this end, and using the crosstab() function from pandas, generate the 4 following graphs :
# - Pie plot and bivariate histogram of the class depending on the survival status
# - Pie plot and bivariate histogram of survival status based on the class

# %%
ct = pd.crosstab(titanic_data['Pclass'],titanic_data['Survived'])
ct.plot.bar(rot=0)
# Out:
# <Axes: xlabel='Pclass'>

# %%
ct.plot(kind='pie', subplots=True,autopct='%1.1f%%', figsize=(8, 8))
# Out:
# array([<Axes: ylabel='0'>, <Axes: ylabel='1'>], dtype=object)

# %%
ct2 = pd.crosstab(titanic_data['Survived'],titanic_data['Pclass'])
ct2.plot.bar(rot=0)
# Out:
# <Axes: xlabel='Survived'>

# %%
ct2.plot(kind='pie', subplots=True,autopct='%1.1f%%', figsize=(16, 8))
# Out:
# array([<Axes: ylabel='1'>, <Axes: ylabel='2'>, <Axes: ylabel='3'>],
#       dtype=object)

# %% [markdown]
# #### Question 9 : Explain what each of the different visualization brings, and comment on an eventual link between the travel class and chances of survival.

# %% [markdown]
# <u>Answer 9 :</u>
#
# *Your answer*

# %% [markdown]
# We will now take a look at how the "women and children first" policy was respected (or not) on board the RMS Titanic given that there was only a limited number of lifeboat. To do so, we first create a "Status" column to filter the passengers into 4 categories "adult male", "adult female", "female child" and "male child". Please note that we make the choice of considering passengers of unknown age as adults.

# %%
titanic_data['Status'] = titanic_data.loc[:, 'Sex']
titanic_data.loc[ titanic_data["Sex"]=="male" , 'Status' ]="adult male"
titanic_data.loc[ titanic_data["Sex"]=="female" , 'Status' ]="adult female"
titanic_data.loc[ (titanic_data["Age"]<18) & (titanic_data["Sex"]=="female") , 'Status' ]="female child"
titanic_data.loc[ (titanic_data["Age"]<18) & (titanic_data["Sex"]=="male") , 'Status' ]="male child"
titanic_data
# Out:
#              Survived  Pclass       Name  \
# PassengerId
# 1                   0       3     Braund
# 2                   1       1    Cumings
# 3                   1       3  Heikkinen
# 4                   1       1   Futrelle
# 5                   0       3      Allen
# ...               ...     ...        ...
# 888                 1       1     Graham
# 889                 0       3   Johnston
# 890                 1       1       Behr
# 891                 0       3     Dooley
# 892                 1       1      Brown
#
#                                                 FullName     Sex   Age  SibSp  \
# PassengerId
# 1                                        Mr. Owen Harris    male  22.0      1
# 2             Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 3                                            Miss. Laina  female  26.0      0
# 4                     Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                                      Mr. William Henry    male  35.0      0
# ...                                                  ...     ...   ...    ...
# 888                                 Miss. Margaret Edith  female  19.0      0
# 889                         Miss. Catherine Helen Carrie  female   NaN      1
# 890                                      Mr. Karl Howell    male  26.0      0
# 891                                          Mr. Patrick    male  32.0      0
# 892                                      Miss. Margareth  female  45.0      0
#
#              Parch            Ticket     Fare Cabin Embarked        Status
# PassengerId
# 1                0         A/5 21171   7.2500   NaN        S    adult male
# 2                0          PC 17599  71.2833   C85        C  adult female
# 3                0  STON/O2. 3101282   7.9250   NaN        S  adult female
# 4                0            113803  53.1000  C123        S  adult female
# 5                0            373450   8.0500   NaN        S    adult male
# ...            ...               ...      ...   ...      ...           ...
# 888              0            112053  30.0000   B42        S  adult female
# 889              2        W./C. 6607  23.4500   NaN        S  adult female
# 890              0            111369  30.0000  C148        C    adult male
# 891              0            370376   7.7500   NaN        Q    adult male
# 892              0             17610  27.1400   E23        C  adult female
#
# [892 rows x 13 columns]

# %% [markdown]
# #### Question 10 : Using the previous visualizations and the newly created variable, propose one or several useful graphics to comment on the "women and children first policy" on board the RMS Titanic.

# %%
#bloc de code pour la question 10 (vous pouvez en utiliser/créer d'autres)
ct3 = pd.crosstab(titanic_data['Survived'],titanic_data['Status'])
ct3.plot(kind='pie', subplots=True,autopct='%1.1f%%', figsize=(16, 16))
# Out:
# array([<Axes: ylabel='adult female'>, <Axes: ylabel='adult male'>,
#        <Axes: ylabel='female child'>, <Axes: ylabel='male child'>],
#       dtype=object)

# %% [markdown]
# <u>Answer 10</u>
#
# *Your answer*

# %% [markdown]
# ## Part B : Machine Learning
#
# In this section and using simple ML methods, we will try to predict who survives and who dies based on the various known informations about the passengers.
#
# We begin by importing some necessary libraries for decision trees and Machine Learning.

# %%
from IPython.display import Image
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import tree
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
titanic_data
# Out:
#              Survived  Pclass       Name  \
# PassengerId
# 1                   0       3     Braund
# 2                   1       1    Cumings
# 3                   1       3  Heikkinen
# 4                   1       1   Futrelle
# 5                   0       3      Allen
# ...               ...     ...        ...
# 888                 1       1     Graham
# 889                 0       3   Johnston
# 890                 1       1       Behr
# 891                 0       3     Dooley
# 892                 1       1      Brown
#
#                                                 FullName     Sex   Age  SibSp  \
# PassengerId
# 1                                        Mr. Owen Harris    male  22.0      1
# 2             Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 3                                            Miss. Laina  female  26.0      0
# 4                     Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                                      Mr. William Henry    male  35.0      0
# ...                                                  ...     ...   ...    ...
# 888                                 Miss. Margaret Edith  female  19.0      0
# 889                         Miss. Catherine Helen Carrie  female   NaN      1
# 890                                      Mr. Karl Howell    male  26.0      0
# 891                                          Mr. Patrick    male  32.0      0
# 892                                      Miss. Margareth  female  45.0      0
#
#              Parch            Ticket     Fare Cabin Embarked        Status
# PassengerId
# 1                0         A/5 21171   7.2500   NaN        S    adult male
# 2                0          PC 17599  71.2833   C85        C  adult female
# 3                0  STON/O2. 3101282   7.9250   NaN        S  adult female
# 4                0            113803  53.1000  C123        S  adult female
# 5                0            373450   8.0500   NaN        S    adult male
# ...            ...               ...      ...   ...      ...           ...
# 888              0            112053  30.0000   B42        S  adult female
# 889              2        W./C. 6607  23.4500   NaN        S  adult female
# 890              0            111369  30.0000  C148        C    adult male
# 891              0            370376   7.7500   NaN        Q    adult male
# 892              0             17610  27.1400   E23        C  adult female
#
# [892 rows x 13 columns]

# %% [markdown]
# Unfortunately, decision trees in Python only handle numerical data. Therefore, our "Status" variable cannot be used, and we must consider creating the 2 following columns instead :
# - A variable "Male" whose value is 1 for male passengers and 0 for female
# - A variable "Kid" whose value is 1 for children and 0 otherwise
#
# #### Question 1 : Create these two variables :

# %%
titanic_data["Male"]=titanic_data["Sex"]
titanic_data["Male"][titanic_data['Sex'] == "male"]=1
titanic_data["Male"][titanic_data['Sex'] != "male"]=0

titanic_data["Kid"]=titanic_data["Sex"]
titanic_data["Kid"]=0
titanic_data["Kid"][titanic_data['Age'] < 18]=1

# %% [markdown]
# #### Question 2 : What does the code below do ? Explain the role of each variable that the "train_test_split" function creates as well as the different parameters.

# %%
target_labels=titanic_data.Survived
train_predictor_columns = ['Pclass', 'Fare', 'Male', 'Kid'] #we will predict from the variables
train_feats = titanic_data[train_predictor_columns]

x_train,x_test,y_train,y_test  = train_test_split(train_feats,target_labels, test_size=0.2, random_state = 0)

# %% [markdown]
# <u>Answer 2 :</u>
#
# It defines the variables used for prediction and the target variables. Then it splits the dataset between training and test set with a 80/20 split.

# %% [markdown]
# We will now train a decision tree with a depth of 3

# %%
clf =tree.DecisionTreeClassifier(max_depth=3) #On peut jouer sur la profondeur de l'arbre ici
clf=clf.fit(x_train, y_train)

# %% [markdown]
# #### Question 3 : Using the "classification_report" function from "metrics" with the right parameters, display the metrics associated with this decision tree and comment. In particular, explain what are the different metrics proposed.

# %%
y_pred = clf.predict(x_train[train_predictor_columns])
#display the metrics
print(metrics.classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.96      0.87       441
#            1       0.90      0.60      0.72       272
#
#     accuracy                           0.82       713
#    macro avg       0.85      0.78      0.80       713
# weighted avg       0.83      0.82      0.81       713

# %% [markdown]
# <u>Answer 3</u>
#
# It shows various dice metrics on the training set.

# %% [markdown]
# The code below will display the decision tree (you might have to adjust the figsize to match with your screen resolution) :

# %%
plt.figure(figsize=(12,12))
tree.plot_tree(clf,feature_names=train_predictor_columns,class_names=["Survived","Died"])
# Out:
# [Text(0.5, 0.875, 'Male <= 0.5\ngini = 0.472\nsamples = 713\nvalue = [441, 272]\nclass = Survived'),
#  Text(0.25, 0.625, 'Pclass <= 2.5\ngini = 0.361\nsamples = 237\nvalue = [56, 181]\nclass = Died'),
#  Text(0.125, 0.375, 'Fare <= 149.035\ngini = 0.089\nsamples = 129\nvalue = [6, 123]\nclass = Died'),
#  Text(0.0625, 0.125, 'gini = 0.067\nsamples = 116\nvalue = [4, 112]\nclass = Died'),
#  Text(0.1875, 0.125, 'gini = 0.26\nsamples = 13\nvalue = [2, 11]\nclass = Died'),
#  Text(0.375, 0.375, 'Fare <= 8.04\ngini = 0.497\nsamples = 108\nvalue = [50, 58]\nclass = Died'),
#  Text(0.3125, 0.125, 'gini = 0.326\nsamples = 39\nvalue = [8, 31]\nclass = Died'),
#  Text(0.4375, 0.125, 'gini = 0.476\nsamples = 69\nvalue = [42, 27]\nclass = Survived'),
#  Text(0.75, 0.625, 'Fare <= 26.269\ngini = 0.309\nsamples = 476\nvalue = [385, 91]\nclass = Survived'),
#  Text(0.625, 0.375, 'Kid <= 0.5\ngini = 0.24\nsamples = 344\nvalue = [296, 48]\nclass = Survived'),
#  Text(0.5625, 0.125, 'gini = 0.206\nsamples = 318\nvalue = [281, 37]\nclass = Survived'),
#  Text(0.6875, 0.125, 'gini = 0.488\nsamples = 26\nvalue = [15, 11]\nclass = Survived'),
#  Text(0.875, 0.375, 'Fare <= 26.775\ngini = 0.439\nsamples = 132\nvalue = [89, 43]\nclass = Survived'),
#  Text(0.8125, 0.125, 'gini = 0.444\nsamples = 15\nvalue = [5, 10]\nclass = Died'),
#  Text(0.9375, 0.125, 'gini = 0.405\nsamples = 117\nvalue = [84, 33]\nclass = Survived')]

# %% [markdown]
# #### Question 4 : Comment on the resulting tree. In particular, you will explain what are the "gini", "samples", and "value" in each branch referring to.

# %% [markdown]
# <u>Answer 4 : </u>
#
# *Your answer*

# %% [markdown]
# #### Question 5 : Translate this decision tree into simple clauses. Is it coherent ?

# %% [markdown]
# <u>Answer 5:</u>
#
# *Your answer*

# %% [markdown]
# #### Question 6 : Apply the same decision tree to your test set for a prediction task and generate the associated quality metric. Comment your results by comparison with the training prediction values.

# %%
y_pred = clf.predict(x_test[train_predictor_columns])
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.83       108
#            1       0.78      0.61      0.68        71
#
#     accuracy                           0.78       179
#    macro avg       0.78      0.75      0.76       179
# weighted avg       0.78      0.78      0.77       179

# %% [markdown]
# <u>Answer 6:</u>
#
# *Your answer*
